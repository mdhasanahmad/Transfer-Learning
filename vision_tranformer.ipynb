# %% [markdown]
# <a href="https://colab.research.google.com/github/hasanahmad676/Transfer-Learning/blob/main/vision_tranformer.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
! nvidia-smi
# Out:
# Mon Aug 14 14:54:11 2023
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 525.105.17   Driver Version: 525.105.17   CUDA Version: 12.0     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   57C    P8    10W /  70W |      0MiB / 15360MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import matplotlib.pyplot as plt
import seaborn as sns

import keras
from keras.models import Sequential
from keras.layers import Dense, Conv2D , MaxPool2D , Flatten , Dropout
from keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.optimizers import Adam

from sklearn.metrics import classification_report,confusion_matrix

import tensorflow as tf

import cv2
import os

import numpy as np

# %%
labels = ["OSCC", "Normal"]
img_size = 32
def get_data(data_dir):
    data = []
    for label in labels:
        path = os.path.join(data_dir, label)
        class_num = labels.index(label)
        for img in os.listdir(path):
            try:
                img_arr = cv2.imread(os.path.join(path, img))[...,::-1] #convert BGR to RGB format
                resized_arr = cv2.resize(img_arr, (img_size, img_size)) # Reshaping images to preferred size
                data.append([resized_arr, class_num])
            except Exception as e:
                print(e)
    return np.array(data)

# %%
train = get_data('/content/drive/MyDrive/rose leaf disease/separate original data/Train Dataset')
# Out:
# <ipython-input-6-8ea74eee6c96>:15: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   return np.array(data)

# %%
import pandas as pd

l = []
for i in train:
    if(i[1] == 0):
        l.append("Black Spot")
    elif(i[1] == 1):
          l.append("Downy Mildew")
    elif(i[1] == 2):
          l.append("Fresh Leaf")


if len(l) > 0:
    sns.set_style('darkgrid')
    sns.countplot(x="label", hue="class", data=pd.DataFrame({"label": l, "class": train[:, 1]}))
    plt.show()
else:
    print("No data found for the given labels.")

# %%
plt.figure(figsize = (5,5))
plt.imshow(train[1][0])
plt.title(labels[train[0][1]])
# Out:
# Text(0.5, 1.0, 'Black Spot')

# %%
x_train = []
y_train = []


for feature, label in train:
  x_train.append(feature)
  y_train.append(label)
x_train = np.array(x_train) / 255
x_train.reshape(-1, img_size, img_size, 1)
y_train = np.array(y_train)

# %%
print(x_train.shape)
# Out:
# (640, 32, 32, 3)

# %%
# split with a stratified sampling
from sklearn.model_selection import train_test_split
(x_train, x_test, y_train, y_test) = train_test_split(x_train, y_train,
    test_size=0.20, stratify=y_train, random_state=42)

# %%
# !pip install -U -q tensorflow-addons

# %%
import numpy as np
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
import tensorflow_addons as tfa
# Out:
# /usr/local/lib/python3.10/dist-packages/tensorflow_addons/utils/tfa_eol_msg.py:23: UserWarning:
#
# TensorFlow Addons (TFA) has ended development and introduction of new features.
# TFA has entered a minimal maintenance and release mode until a planned end of life in May 2024.
# Please modify downstream libraries to take dependencies from other repositories in our TensorFlow community (e.g. Keras, Keras-CV, and Keras-NLP).
#
# For more information see: https://github.com/tensorflow/addons/issues/2807
#
#   warnings.warn(

# %%
num_classes = 3
input_shape = (32, 32, 3)

# %%
print(f"x_train shape: {x_train.shape} - y_train shape: {y_train.shape}")
print(f"x_test shape: {x_test.shape} - y_test shape: {y_test.shape}")
# Out:
# x_train shape: (512, 32, 32, 3) - y_train shape: (512,)
# x_test shape: (128, 32, 32, 3) - y_test shape: (128,)

# %%
learning_rate = 0.001
weight_decay = 0.0001
batch_size = 128
num_epochs = 100
image_size = 32  # We'll resize input images to this size
patch_size = 6  # Size of the patches to be extract from the input images
num_patches = (image_size // patch_size) ** 2
projection_dim = 64
num_heads = 2
transformer_units = [
    projection_dim * 2,
    projection_dim,
]  # Size of the transformer layers
transformer_layers = 1
mlp_head_units = [2048, 1024]

# %%
data_augmentation = keras.Sequential(
    [
        layers.Normalization(),
        layers.Resizing(image_size, image_size),
        layers.RandomFlip("horizontal"),
        layers.RandomRotation(factor=0.02),
        layers.RandomZoom(
            height_factor=0.2, width_factor=0.2
        ),
    ],
    name="data_augmentation",
)
# Compute the mean and the variance of the training data for normalization.
data_augmentation.layers[0].adapt(x_train)

# %%
def mlp(x, hidden_units, dropout_rate):
    for units in hidden_units:
        x = layers.Dense(units, activation=tf.nn.gelu)(x)
        x = layers.Dropout(dropout_rate)(x)
    return x

# %%
class Patches(layers.Layer):
    def __init__(self, patch_size):
        super(Patches, self).__init__()
        self.patch_size = patch_size

    def call(self, images):
        batch_size = tf.shape(images)[0]
        patches = tf.image.extract_patches(
            images=images,
            sizes=[1, self.patch_size, self.patch_size, 1],
            strides=[1, self.patch_size, self.patch_size, 1],
            rates=[1, 1, 1, 1],
            padding="VALID",
        )
        patch_dims = patches.shape[-1]
        patches = tf.reshape(patches, [batch_size, -1, patch_dims])
        return patches

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(4, 4))
image = x_train[np.random.choice(range(x_train.shape[0]))]
plt.imshow(image.astype("float"))
plt.axis("off")

resized_image = tf.image.resize(
    tf.convert_to_tensor([image]), size=(image_size, image_size)
)
patches = Patches(patch_size)(resized_image)
print(f"Image size: {image_size} X {image_size}")
print(f"Patch size: {patch_size} X {patch_size}")
print(f"Patches per image: {patches.shape[1]}")
print(f"Elements per patch: {patches.shape[-1]}")

n = int(np.sqrt(patches.shape[1]))
plt.figure(figsize=(4, 4))
for i, patch in enumerate(patches[0]):
    ax = plt.subplot(n, n, i + 1)
    patch_img = tf.reshape(patch, (patch_size, patch_size, 3))
    plt.imshow(patch_img.numpy().astype("float"))
    plt.axis("off")
# Out:
# Image size: 32 X 32
# Patch size: 6 X 6
# Patches per image: 25
# Elements per patch: 108

# %%
class PatchEncoder(layers.Layer):
    def __init__(self, num_patches, projection_dim):
        super(PatchEncoder, self).__init__()
        self.num_patches = num_patches
        self.projection = layers.Dense(units=projection_dim)
        self.position_embedding = layers.Embedding(
            input_dim=num_patches, output_dim=projection_dim
        )

    def call(self, patch):
        positions = tf.range(start=0, limit=self.num_patches, delta=1)
        encoded = self.projection(patch) + self.position_embedding(positions)
        return encoded

# %%
def create_vit_classifier():
    inputs = layers.Input(shape=input_shape)
    # Augment data.
    augmented = data_augmentation(inputs)
    # Create patches.
    patches = Patches(patch_size)(augmented)
    # Encode patches.
    encoded_patches = PatchEncoder(num_patches, projection_dim)(patches)

    # Create multiple layers of the Transformer block.
    for _ in range(transformer_layers):
        # Layer normalization 1.
        x1 = layers.LayerNormalization(epsilon=1e-6)(encoded_patches)
        # Create a multi-head attention layer.
        attention_output = layers.MultiHeadAttention(
            num_heads=num_heads, key_dim=projection_dim, dropout=0.1
        )(x1, x1)
        # Skip connection 1.
        x2 = layers.Add()([attention_output, encoded_patches])
        # Layer normalization 2.
        x3 = layers.LayerNormalization(epsilon=1e-6)(x2)
        # MLP.
        x3 = mlp(x3, hidden_units=transformer_units, dropout_rate=0.1)
        # Skip connection 2.
        encoded_patches = layers.Add()([x3, x2])

    # Create a [batch_size, projection_dim] tensor.
    representation = layers.LayerNormalization(epsilon=1e-6)(encoded_patches)
    representation = layers.Flatten()(representation)
    representation = layers.Dropout(0.5)(representation)
    # Add MLP.
    features = mlp(representation, hidden_units=mlp_head_units, dropout_rate=0.5)
    # Classify outputs.
    logits = layers.Dense(num_classes)(features)
    # Create the Keras model.
    model = keras.Model(inputs=inputs, outputs=logits)
    return model

# %%
def run_experiment(model):
    optimizer = tfa.optimizers.AdamW(
        learning_rate=learning_rate, weight_decay=weight_decay
    )

    model.compile(
        optimizer=optimizer,
        loss=keras.losses.SparseCategoricalCrossentropy(from_logits=True),
        metrics=[
            keras.metrics.SparseCategoricalAccuracy(name="accuracy"),
            keras.metrics.SparseTopKCategoricalAccuracy(5, name="top-5-accuracy"),
        ],
    )

    checkpoint_filepath = "/content/sample_data/Vit_h5/model.h5"
    checkpoint_callback = keras.callbacks.ModelCheckpoint(
        checkpoint_filepath,
        monitor="val_accuracy",
        save_best_only=True,
        save_weights_only=True,
    )

    history = model.fit(
        x=x_train,
        y=y_train,
        batch_size=batch_size,
        epochs=num_epochs,
        validation_split=0.15,
        callbacks=[checkpoint_callback],
    )

    model.load_weights(checkpoint_filepath)
    _, accuracy, top_5_accuracy = model.evaluate(x_test, y_test)
    print(f"Test accuracy: {round(accuracy * 100, 2)}%")
    print(f"Test top 5 accuracy: {round(top_5_accuracy * 100, 2)}%")
    from sklearn.metrics import classification_report, confusion_matrix

    # as I've trained my model on MNIST as odd or even (binary classes)
    target_names = ["Black Spot", "Downy Mildew","Fresh Leaf"]


    # get predict prob and label
    ypred = model.predict(x_test, verbose=1)
    ypred = np.argmax(ypred, axis=1)
    print(classification_report(y_test, ypred, target_names=target_names))
    import matplotlib.pyplot as plt
    import seaborn as sns
    import pandas as pd

    cm = confusion_matrix(y_test, ypred)
    cm = pd.DataFrame(cm, range(3),range(3))
    plt.figure(figsize = (10,10))

    sns.heatmap(cm, annot=True, annot_kws={"size": 12}) # font size
    plt.show()
    return history


vit_classifier = create_vit_classifier()
history = run_experiment(vit_classifier)
# Out:
# Epoch 1/100
# 4/4 [==============================] - 4s 167ms/step - loss: 1.7674 - accuracy: 0.4943 - top-5-accuracy: 1.0000 - val_loss: 0.9483 - val_accuracy: 0.6753 - val_top-5-accuracy: 1.0000
# Epoch 2/100
# 4/4 [==============================] - 0s 42ms/step - loss: 1.5339 - accuracy: 0.6345 - top-5-accuracy: 1.0000 - val_loss: 0.5914 - val_accuracy: 0.7403 - val_top-5-accuracy: 1.0000
# Epoch 3/100
# 4/4 [==============================] - 0s 26ms/step - loss: 1.1752 - accuracy: 0.6644 - top-5-accuracy: 1.0000 - val_loss: 0.6283 - val_accuracy: 0.7403 - val_top-5-accuracy: 1.0000
# Epoch 4/100
# 4/4 [==============================] - 0s 42ms/step - loss: 1.0498 - accuracy: 0.6460 - top-5-accuracy: 1.0000 - val_loss: 0.5284 - val_accuracy: 0.7532 - val_top-5-accuracy: 1.0000
# Epoch 5/100
# 4/4 [==============================] - 0s 49ms/step - loss: 0.8539 - accuracy: 0.6598 - top-5-accuracy: 1.0000 - val_loss: 0.5174 - val_accuracy: 0.7662 - val_top-5-accuracy: 1.0000
# Epoch 6/100
# 4/4 [==============================] - 0s 45ms/step - loss: 0.6643 - accuracy: 0.7241 - top-5-accuracy: 1.0000 - val_loss: 0.4435 - val_accuracy: 0.8182 - val_top-5-accuracy: 1.0000
# Epoch 7/100
# 4/4 [==============================] - 0s 24ms/step - loss: 0.8122 - accuracy: 0.6851 - top-5-accuracy: 1.0000 - val_loss: 0.4417 - val_accuracy: 0.8182 - val_top-5-accuracy: 1.0000
# Epoch 8/100
# 4/4 [==============================] - 0s 24ms/step - loss: 0.6517 - accuracy: 0.6920 - top-5-accuracy: 1.0000 - val_loss: 0.5166 - val_accuracy: 0.7532 - val_top-5-accuracy: 1.0000
# Epoch 9/100
# 4/4 [==============================] - 0s 23ms/step - loss: 0.6233 - accuracy: 0.7287 - top-5-accuracy: 1.0000 - val_loss: 0.4639 - val_accuracy: 0.7922 - val_top-5-accuracy: 1.0000
# Epoch 10/100
# 4/4 [==============================] - 0s 29ms/step - loss: 0.6371 - accuracy: 0.7402 - top-5-accuracy: 1.0000 - val_loss: 0.4673 - val_accuracy: 0.8182 - val_top-5-accuracy: 1.0000
# Epoch 11/100
# 4/4 [==============================] - 0s 24ms/step - loss: 0.6593 - accuracy: 0.7218 - top-5-accuracy: 1.0000 - val_loss: 0.4588 - val_accuracy: 0.8052 - val_top-5-accuracy: 1.0000
# Epoch 12/100
# 4/4 [==============================] - 0s 29ms/step - loss: 0.5225 - accuracy: 0.7747 - top-5-accuracy: 1.0000 - val_loss: 0.5194 - val_accuracy: 0.7792 - val_top-5-accuracy: 1.0000
# Epoch 13/100
# 4/4 [==============================] - 0s 29ms/step - loss: 0.5615 - accuracy: 0.7241 - top-5-accuracy: 1.0000 - val_loss: 0.6167 - val_accuracy: 0.7013 - val_top-5-accuracy: 1.0000
# Epoch 14/100
# 4/4 [==============================] - 0s 28ms/step - loss: 0.5603 - accuracy: 0.7563 - top-5-accuracy: 1.0000 - val_loss: 0.5136 - val_accuracy: 0.7922 - val_top-5-accuracy: 1.0000
# Epoch 15/100
# 4/4 [==============================] - 0s 24ms/step - loss: 0.5029 - accuracy: 0.7770 - top-5-accuracy: 1.0000 - val_loss: 0.4776 - val_accuracy: 0.8182 - val_top-5-accuracy: 1.0000
# Epoch 16/100
# 4/4 [==============================] - 0s 49ms/step - loss: 0.5368 - accuracy: 0.7494 - top-5-accuracy: 1.0000 - val_loss: 0.4559 - val_accuracy: 0.8701 - val_top-5-accuracy: 1.0000
# Epoch 17/100
# 4/4 [==============================] - 0s 30ms/step - loss: 0.4866 - accuracy: 0.7793 - top-5-accuracy: 1.0000 - val_loss: 0.4618 - val_accuracy: 0.8442 - val_top-5-accuracy: 1.0000
# Epoch 18/100
# 4/4 [==============================] - 0s 50ms/step - loss: 0.4706 - accuracy: 0.7816 - top-5-accuracy: 1.0000 - val_loss: 0.4397 - val_accuracy: 0.8961 - val_top-5-accuracy: 1.0000
# Epoch 19/100
# 4/4 [==============================] - 0s 27ms/step - loss: 0.4849 - accuracy: 0.7885 - top-5-accuracy: 1.0000 - val_loss: 0.4283 - val_accuracy: 0.8571 - val_top-5-accuracy: 1.0000
# Epoch 20/100
# 4/4 [==============================] - 0s 29ms/step - loss: 0.4347 - accuracy: 0.7747 - top-5-accuracy: 1.0000 - val_loss: 0.4165 - val_accuracy: 0.8312 - val_top-5-accuracy: 1.0000
# Epoch 21/100
# 4/4 [==============================] - 0s 26ms/step - loss: 0.4897 - accuracy: 0.7816 - top-5-accuracy: 1.0000 - val_loss: 0.4490 - val_accuracy: 0.8312 - val_top-5-accuracy: 1.0000
# Epoch 22/100
# 4/4 [==============================] - 0s 30ms/step - loss: 0.4335 - accuracy: 0.8046 - top-5-accuracy: 1.0000 - val_loss: 0.4283 - val_accuracy: 0.8571 - val_top-5-accuracy: 1.0000
# Epoch 23/100
# 4/4 [==============================] - 0s 30ms/step - loss: 0.4078 - accuracy: 0.8000 - top-5-accuracy: 1.0000 - val_loss: 0.4308 - val_accuracy: 0.8312 - val_top-5-accuracy: 1.0000
# Epoch 24/100
# 4/4 [==============================] - 0s 25ms/step - loss: 0.4430 - accuracy: 0.7885 - top-5-accuracy: 1.0000 - val_loss: 0.4599 - val_accuracy: 0.8182 - val_top-5-accuracy: 1.0000
# Epoch 25/100
# 4/4 [==============================] - 0s 24ms/step - loss: 0.3994 - accuracy: 0.8299 - top-5-accuracy: 1.0000 - val_loss: 0.4260 - val_accuracy: 0.8312 - val_top-5-accuracy: 1.0000
# Epoch 26/100
# 4/4 [==============================] - 0s 25ms/step - loss: 0.3859 - accuracy: 0.8161 - top-5-accuracy: 1.0000 - val_loss: 0.4027 - val_accuracy: 0.8312 - val_top-5-accuracy: 1.0000
# Epoch 27/100
# 4/4 [==============================] - 0s 30ms/step - loss: 0.3905 - accuracy: 0.8138 - top-5-accuracy: 1.0000 - val_loss: 0.4057 - val_accuracy: 0.8442 - val_top-5-accuracy: 1.0000
# Epoch 28/100
# 4/4 [==============================] - 0s 24ms/step - loss: 0.4013 - accuracy: 0.7954 - top-5-accuracy: 1.0000 - val_loss: 0.4595 - val_accuracy: 0.8052 - val_top-5-accuracy: 1.0000
# Epoch 29/100
# 4/4 [==============================] - 0s 23ms/step - loss: 0.4448 - accuracy: 0.7839 - top-5-accuracy: 1.0000 - val_loss: 0.4833 - val_accuracy: 0.7922 - val_top-5-accuracy: 1.0000
# Epoch 30/100
# 4/4 [==============================] - 0s 30ms/step - loss: 0.3754 - accuracy: 0.8391 - top-5-accuracy: 1.0000 - val_loss: 0.4116 - val_accuracy: 0.8312 - val_top-5-accuracy: 1.0000
# Epoch 31/100
# 4/4 [==============================] - 0s 25ms/step - loss: 0.3524 - accuracy: 0.8276 - top-5-accuracy: 1.0000 - val_loss: 0.3993 - val_accuracy: 0.8182 - val_top-5-accuracy: 1.0000
# Epoch 32/100
# 4/4 [==============================] - 0s 25ms/step - loss: 0.3509 - accuracy: 0.8460 - top-5-accuracy: 1.0000 - val_loss: 0.4372 - val_accuracy: 0.8571 - val_top-5-accuracy: 1.0000
# Epoch 33/100
# 4/4 [==============================] - 0s 29ms/step - loss: 0.3485 - accuracy: 0.8506 - top-5-accuracy: 1.0000 - val_loss: 0.4310 - val_accuracy: 0.8571 - val_top-5-accuracy: 1.0000
# Epoch 34/100
# 4/4 [==============================] - 0s 23ms/step - loss: 0.3399 - accuracy: 0.8575 - top-5-accuracy: 1.0000 - val_loss: 0.3876 - val_accuracy: 0.8182 - val_top-5-accuracy: 1.0000
# Epoch 35/100
# 4/4 [==============================] - 0s 23ms/step - loss: 0.2951 - accuracy: 0.8759 - top-5-accuracy: 1.0000 - val_loss: 0.3875 - val_accuracy: 0.7792 - val_top-5-accuracy: 1.0000
# Epoch 36/100
# 4/4 [==============================] - 0s 27ms/step - loss: 0.3372 - accuracy: 0.8345 - top-5-accuracy: 1.0000 - val_loss: 0.4138 - val_accuracy: 0.7922 - val_top-5-accuracy: 1.0000
# Epoch 37/100
# 4/4 [==============================] - 0s 23ms/step - loss: 0.3011 - accuracy: 0.8805 - top-5-accuracy: 1.0000 - val_loss: 0.4455 - val_accuracy: 0.7792 - val_top-5-accuracy: 1.0000
# Epoch 38/100
# 4/4 [==============================] - 0s 24ms/step - loss: 0.3510 - accuracy: 0.8598 - top-5-accuracy: 1.0000 - val_loss: 0.4118 - val_accuracy: 0.8312 - val_top-5-accuracy: 1.0000
# Epoch 39/100
# 4/4 [==============================] - 0s 23ms/step - loss: 0.3306 - accuracy: 0.8713 - top-5-accuracy: 1.0000 - val_loss: 0.4083 - val_accuracy: 0.8052 - val_top-5-accuracy: 1.0000
# Epoch 40/100
# 4/4 [==============================] - 0s 25ms/step - loss: 0.2920 - accuracy: 0.8782 - top-5-accuracy: 1.0000 - val_loss: 0.3865 - val_accuracy: 0.8182 - val_top-5-accuracy: 1.0000
# Epoch 41/100
# 4/4 [==============================] - 0s 23ms/step - loss: 0.2854 - accuracy: 0.8966 - top-5-accuracy: 1.0000 - val_loss: 0.3866 - val_accuracy: 0.8831 - val_top-5-accuracy: 1.0000
# Epoch 42/100
# 4/4 [==============================] - 0s 24ms/step - loss: 0.2855 - accuracy: 0.8713 - top-5-accuracy: 1.0000 - val_loss: 0.4640 - val_accuracy: 0.8701 - val_top-5-accuracy: 1.0000
# Epoch 43/100
# 4/4 [==============================] - 0s 27ms/step - loss: 0.3154 - accuracy: 0.8621 - top-5-accuracy: 1.0000 - val_loss: 0.4540 - val_accuracy: 0.8442 - val_top-5-accuracy: 1.0000
# Epoch 44/100
# 4/4 [==============================] - 0s 23ms/step - loss: 0.2929 - accuracy: 0.8828 - top-5-accuracy: 1.0000 - val_loss: 0.3913 - val_accuracy: 0.8571 - val_top-5-accuracy: 1.0000
# Epoch 45/100
# 4/4 [==============================] - 0s 24ms/step - loss: 0.2536 - accuracy: 0.8920 - top-5-accuracy: 1.0000 - val_loss: 0.4282 - val_accuracy: 0.8442 - val_top-5-accuracy: 1.0000
# Epoch 46/100
# 4/4 [==============================] - 0s 23ms/step - loss: 0.3033 - accuracy: 0.8667 - top-5-accuracy: 1.0000 - val_loss: 0.4458 - val_accuracy: 0.8701 - val_top-5-accuracy: 1.0000
# Epoch 47/100
# 4/4 [==============================] - 0s 24ms/step - loss: 0.2721 - accuracy: 0.8736 - top-5-accuracy: 1.0000 - val_loss: 0.4850 - val_accuracy: 0.8442 - val_top-5-accuracy: 1.0000
# Epoch 48/100
# 4/4 [==============================] - 0s 23ms/step - loss: 0.2988 - accuracy: 0.8713 - top-5-accuracy: 1.0000 - val_loss: 0.4212 - val_accuracy: 0.8571 - val_top-5-accuracy: 1.0000
# Epoch 49/100
# 4/4 [==============================] - 0s 23ms/step - loss: 0.2235 - accuracy: 0.8782 - top-5-accuracy: 1.0000 - val_loss: 0.4321 - val_accuracy: 0.8571 - val_top-5-accuracy: 1.0000
# Epoch 50/100
# 4/4 [==============================] - 0s 23ms/step - loss: 0.2878 - accuracy: 0.8782 - top-5-accuracy: 1.0000 - val_loss: 0.4956 - val_accuracy: 0.8312 - val_top-5-accuracy: 1.0000
# Epoch 51/100
# 4/4 [==============================] - 0s 34ms/step - loss: 0.2826 - accuracy: 0.8851 - top-5-accuracy: 1.0000 - val_loss: 0.5414 - val_accuracy: 0.8182 - val_top-5-accuracy: 1.0000
# Epoch 52/100
# 4/4 [==============================] - 0s 32ms/step - loss: 0.2415 - accuracy: 0.8897 - top-5-accuracy: 1.0000 - val_loss: 0.4880 - val_accuracy: 0.8312 - val_top-5-accuracy: 1.0000
# Epoch 53/100
# 4/4 [==============================] - 0s 30ms/step - loss: 0.2541 - accuracy: 0.8920 - top-5-accuracy: 1.0000 - val_loss: 0.4277 - val_accuracy: 0.8571 - val_top-5-accuracy: 1.0000
# Epoch 54/100
# 4/4 [==============================] - 0s 33ms/step - loss: 0.2191 - accuracy: 0.9011 - top-5-accuracy: 1.0000 - val_loss: 0.4739 - val_accuracy: 0.8701 - val_top-5-accuracy: 1.0000
# Epoch 55/100
# 4/4 [==============================] - 0s 30ms/step - loss: 0.2366 - accuracy: 0.9034 - top-5-accuracy: 1.0000 - val_loss: 0.5386 - val_accuracy: 0.8442 - val_top-5-accuracy: 1.0000
# Epoch 56/100
# 4/4 [==============================] - 0s 33ms/step - loss: 0.2031 - accuracy: 0.9080 - top-5-accuracy: 1.0000 - val_loss: 0.4899 - val_accuracy: 0.8442 - val_top-5-accuracy: 1.0000
# Epoch 57/100
# 4/4 [==============================] - 0s 30ms/step - loss: 0.2965 - accuracy: 0.8851 - top-5-accuracy: 1.0000 - val_loss: 0.4676 - val_accuracy: 0.8701 - val_top-5-accuracy: 1.0000
# Epoch 58/100
# 4/4 [==============================] - 0s 36ms/step - loss: 0.2400 - accuracy: 0.9011 - top-5-accuracy: 1.0000 - val_loss: 0.5485 - val_accuracy: 0.8442 - val_top-5-accuracy: 1.0000
# Epoch 59/100
# 4/4 [==============================] - 0s 35ms/step - loss: 0.2541 - accuracy: 0.9034 - top-5-accuracy: 1.0000 - val_loss: 0.4877 - val_accuracy: 0.8571 - val_top-5-accuracy: 1.0000
# Epoch 60/100
# 4/4 [==============================] - 0s 31ms/step - loss: 0.2075 - accuracy: 0.9057 - top-5-accuracy: 1.0000 - val_loss: 0.4506 - val_accuracy: 0.8571 - val_top-5-accuracy: 1.0000
# Epoch 61/100
# 4/4 [==============================] - 0s 34ms/step - loss: 0.1830 - accuracy: 0.9172 - top-5-accuracy: 1.0000 - val_loss: 0.4512 - val_accuracy: 0.8182 - val_top-5-accuracy: 1.0000
# Epoch 62/100
# 4/4 [==============================] - 0s 30ms/step - loss: 0.1568 - accuracy: 0.9333 - top-5-accuracy: 1.0000 - val_loss: 0.4210 - val_accuracy: 0.8442 - val_top-5-accuracy: 1.0000
# Epoch 63/100
# 4/4 [==============================] - 0s 37ms/step - loss: 0.2150 - accuracy: 0.9034 - top-5-accuracy: 1.0000 - val_loss: 0.4259 - val_accuracy: 0.8442 - val_top-5-accuracy: 1.0000
# Epoch 64/100
# 4/4 [==============================] - 0s 35ms/step - loss: 0.1467 - accuracy: 0.9379 - top-5-accuracy: 1.0000 - val_loss: 0.5729 - val_accuracy: 0.8571 - val_top-5-accuracy: 1.0000
# Epoch 65/100
# 4/4 [==============================] - 0s 33ms/step - loss: 0.1817 - accuracy: 0.9310 - top-5-accuracy: 1.0000 - val_loss: 0.5146 - val_accuracy: 0.8571 - val_top-5-accuracy: 1.0000
# Epoch 66/100
# 4/4 [==============================] - 0s 30ms/step - loss: 0.2642 - accuracy: 0.8989 - top-5-accuracy: 1.0000 - val_loss: 0.4805 - val_accuracy: 0.8701 - val_top-5-accuracy: 1.0000
# Epoch 67/100
# 4/4 [==============================] - 0s 32ms/step - loss: 0.2691 - accuracy: 0.9172 - top-5-accuracy: 1.0000 - val_loss: 0.4877 - val_accuracy: 0.8312 - val_top-5-accuracy: 1.0000
# Epoch 68/100
# 4/4 [==============================] - 0s 36ms/step - loss: 0.2416 - accuracy: 0.9126 - top-5-accuracy: 1.0000 - val_loss: 0.4537 - val_accuracy: 0.7922 - val_top-5-accuracy: 1.0000
# Epoch 69/100
# 4/4 [==============================] - 0s 36ms/step - loss: 0.1934 - accuracy: 0.9080 - top-5-accuracy: 1.0000 - val_loss: 0.4909 - val_accuracy: 0.8571 - val_top-5-accuracy: 1.0000
# Epoch 70/100
# 4/4 [==============================] - 0s 36ms/step - loss: 0.1698 - accuracy: 0.9333 - top-5-accuracy: 1.0000 - val_loss: 0.5400 - val_accuracy: 0.8701 - val_top-5-accuracy: 1.0000
# Epoch 71/100
# 4/4 [==============================] - 0s 36ms/step - loss: 0.1620 - accuracy: 0.9333 - top-5-accuracy: 1.0000 - val_loss: 0.4207 - val_accuracy: 0.8571 - val_top-5-accuracy: 1.0000
# Epoch 72/100
# 4/4 [==============================] - 0s 29ms/step - loss: 0.1792 - accuracy: 0.9195 - top-5-accuracy: 1.0000 - val_loss: 0.3495 - val_accuracy: 0.8442 - val_top-5-accuracy: 1.0000
# Epoch 73/100
# 4/4 [==============================] - 0s 31ms/step - loss: 0.1649 - accuracy: 0.9494 - top-5-accuracy: 1.0000 - val_loss: 0.4157 - val_accuracy: 0.8571 - val_top-5-accuracy: 1.0000
# Epoch 74/100
# 4/4 [==============================] - 0s 32ms/step - loss: 0.1467 - accuracy: 0.9333 - top-5-accuracy: 1.0000 - val_loss: 0.4296 - val_accuracy: 0.8701 - val_top-5-accuracy: 1.0000
# Epoch 75/100
# 4/4 [==============================] - 0s 31ms/step - loss: 0.1799 - accuracy: 0.9356 - top-5-accuracy: 1.0000 - val_loss: 0.4437 - val_accuracy: 0.8571 - val_top-5-accuracy: 1.0000
# Epoch 76/100
# 4/4 [==============================] - 0s 39ms/step - loss: 0.1540 - accuracy: 0.9310 - top-5-accuracy: 1.0000 - val_loss: 0.5028 - val_accuracy: 0.8571 - val_top-5-accuracy: 1.0000
# Epoch 77/100
# 4/4 [==============================] - 0s 36ms/step - loss: 0.1601 - accuracy: 0.9379 - top-5-accuracy: 1.0000 - val_loss: 0.5072 - val_accuracy: 0.8571 - val_top-5-accuracy: 1.0000
# Epoch 78/100
# 4/4 [==============================] - 0s 35ms/step - loss: 0.1232 - accuracy: 0.9517 - top-5-accuracy: 1.0000 - val_loss: 0.4589 - val_accuracy: 0.8571 - val_top-5-accuracy: 1.0000
# Epoch 79/100
# 4/4 [==============================] - 0s 32ms/step - loss: 0.1244 - accuracy: 0.9609 - top-5-accuracy: 1.0000 - val_loss: 0.4091 - val_accuracy: 0.8442 - val_top-5-accuracy: 1.0000
# Epoch 80/100
# 4/4 [==============================] - 0s 35ms/step - loss: 0.1437 - accuracy: 0.9425 - top-5-accuracy: 1.0000 - val_loss: 0.4533 - val_accuracy: 0.8442 - val_top-5-accuracy: 1.0000
# Epoch 81/100
# 4/4 [==============================] - 0s 26ms/step - loss: 0.1494 - accuracy: 0.9402 - top-5-accuracy: 1.0000 - val_loss: 0.4833 - val_accuracy: 0.8442 - val_top-5-accuracy: 1.0000
# Epoch 82/100
# 4/4 [==============================] - 0s 23ms/step - loss: 0.1272 - accuracy: 0.9471 - top-5-accuracy: 1.0000 - val_loss: 0.4575 - val_accuracy: 0.8571 - val_top-5-accuracy: 1.0000
# Epoch 83/100
# 4/4 [==============================] - 0s 24ms/step - loss: 0.1727 - accuracy: 0.9287 - top-5-accuracy: 1.0000 - val_loss: 0.4387 - val_accuracy: 0.8831 - val_top-5-accuracy: 1.0000
# Epoch 84/100
# 4/4 [==============================] - 0s 24ms/step - loss: 0.1371 - accuracy: 0.9586 - top-5-accuracy: 1.0000 - val_loss: 0.5461 - val_accuracy: 0.8442 - val_top-5-accuracy: 1.0000
# Epoch 85/100
# 4/4 [==============================] - 0s 29ms/step - loss: 0.1672 - accuracy: 0.9310 - top-5-accuracy: 1.0000 - val_loss: 0.4541 - val_accuracy: 0.8961 - val_top-5-accuracy: 1.0000
# Epoch 86/100
# 4/4 [==============================] - 0s 24ms/step - loss: 0.1597 - accuracy: 0.9425 - top-5-accuracy: 1.0000 - val_loss: 0.4116 - val_accuracy: 0.8701 - val_top-5-accuracy: 1.0000
# Epoch 87/100
# 4/4 [==============================] - 0s 28ms/step - loss: 0.1311 - accuracy: 0.9563 - top-5-accuracy: 1.0000 - val_loss: 0.3967 - val_accuracy: 0.8701 - val_top-5-accuracy: 1.0000
# Epoch 88/100
# 4/4 [==============================] - 0s 23ms/step - loss: 0.1585 - accuracy: 0.9448 - top-5-accuracy: 1.0000 - val_loss: 0.3375 - val_accuracy: 0.8571 - val_top-5-accuracy: 1.0000
# Epoch 89/100
# 4/4 [==============================] - 0s 24ms/step - loss: 0.1504 - accuracy: 0.9402 - top-5-accuracy: 1.0000 - val_loss: 0.3692 - val_accuracy: 0.8701 - val_top-5-accuracy: 1.0000
# Epoch 90/100
# 4/4 [==============================] - 0s 24ms/step - loss: 0.1653 - accuracy: 0.9218 - top-5-accuracy: 1.0000 - val_loss: 0.4547 - val_accuracy: 0.8831 - val_top-5-accuracy: 1.0000
# Epoch 91/100
# 4/4 [==============================] - 0s 29ms/step - loss: 0.1792 - accuracy: 0.9402 - top-5-accuracy: 1.0000 - val_loss: 0.3474 - val_accuracy: 0.8831 - val_top-5-accuracy: 1.0000
# Epoch 92/100
# 4/4 [==============================] - 0s 24ms/step - loss: 0.1618 - accuracy: 0.9264 - top-5-accuracy: 1.0000 - val_loss: 0.4074 - val_accuracy: 0.8571 - val_top-5-accuracy: 1.0000
# Epoch 93/100
# 4/4 [==============================] - 0s 29ms/step - loss: 0.1284 - accuracy: 0.9563 - top-5-accuracy: 1.0000 - val_loss: 0.4873 - val_accuracy: 0.8701 - val_top-5-accuracy: 1.0000
# Epoch 94/100
# 4/4 [==============================] - 0s 24ms/step - loss: 0.1434 - accuracy: 0.9494 - top-5-accuracy: 1.0000 - val_loss: 0.5355 - val_accuracy: 0.8701 - val_top-5-accuracy: 1.0000
# Epoch 95/100
# 4/4 [==============================] - 0s 25ms/step - loss: 0.1924 - accuracy: 0.9264 - top-5-accuracy: 1.0000 - val_loss: 0.4902 - val_accuracy: 0.8831 - val_top-5-accuracy: 1.0000
# Epoch 96/100
# 4/4 [==============================] - 0s 28ms/step - loss: 0.1737 - accuracy: 0.9287 - top-5-accuracy: 1.0000 - val_loss: 0.4446 - val_accuracy: 0.8961 - val_top-5-accuracy: 1.0000
# Epoch 97/100
# 4/4 [==============================] - 0s 24ms/step - loss: 0.0907 - accuracy: 0.9655 - top-5-accuracy: 1.0000 - val_loss: 0.3787 - val_accuracy: 0.8831 - val_top-5-accuracy: 1.0000
# Epoch 98/100
# 4/4 [==============================] - 0s 24ms/step - loss: 0.1451 - accuracy: 0.9448 - top-5-accuracy: 1.0000 - val_loss: 0.3300 - val_accuracy: 0.8571 - val_top-5-accuracy: 1.0000
# Epoch 99/100
# 4/4 [==============================] - 0s 23ms/step - loss: 0.0931 - accuracy: 0.9655 - top-5-accuracy: 1.0000 - val_loss: 0.3375 - val_accuracy: 0.8961 - val_top-5-accuracy: 1.0000
# Epoch 100/100
# 4/4 [==============================] - 0s 28ms/step - loss: 0.1678 - accuracy: 0.9356 - top-5-accuracy: 1.0000 - val_loss: 0.3701 - val_accuracy: 0.8831 - val_top-5-accuracy: 1.0000
# 4/4 [==============================] - 0s 7ms/step - loss: 0.6235 - accuracy: 0.6797 - top-5-accuracy: 1.0000
# Test accuracy: 67.97%
# Test top 5 accuracy: 100.0%
# 4/4 [==============================] - 1s 4ms/step
#               precision    recall  f1-score   support
#
#   Black Spot       0.55      0.53      0.54        43
# Downy Mildew       0.90      0.96      0.93        28
#   Fresh Leaf       0.66      0.65      0.65        57
#
#     accuracy                           0.68       128
#    macro avg       0.70      0.72      0.71       128
# weighted avg       0.68      0.68      0.68       128

# %%
plt.figure(figsize=(15,10))
plt.plot(history.history["loss"],label = "training loss")
plt.plot(history.history["val_loss"],label = "validation loss")
plt.title("Training Loss & Validation Loss")
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.legend()
plt.show()

plt.figure(figsize=(15,10))
plt.plot(history.history["accuracy"],label = "training acc")
plt.plot(history.history["val_accuracy"],label = "validation acc")
plt.title("Training Accuracy & Validation Accuracy")
plt.xlabel("Epoch")
plt.ylabel("Accuracy")
plt.legend()
plt.show()
