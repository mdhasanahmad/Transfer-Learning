# %%
! nvidia-smi
# Out:
# Sat Sep 10 14:09:00 2022
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 460.32.03    Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   44C    P8     9W /  70W |      0MiB / 15109MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !unzip -u "/content/drive/MyDrive/OCT Project/OCT Code & Dataset/Image Processing/Alpha Beta on Median Erosion/DMEA.zip" -d "/content/OCT_Dataset"

print('\n\ndone!')

# %%
import matplotlib.pyplot as plt
import seaborn as sns

import keras
from keras.models import Sequential
from keras.layers import Dense, Conv2D , MaxPool2D , Flatten , Dropout 
from keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.optimizers import Adam

from sklearn.metrics import classification_report,confusion_matrix

import tensorflow as tf

import cv2
import os

import numpy as np

# %%
labels = ["CNVA", "DMEA","DRUSENA", "NORMALA"]
img_size = 32
def get_data(data_dir):
    data = [] 
    for label in labels: 
        path = os.path.join(data_dir, label)
        class_num = labels.index(label)
        for img in os.listdir(path):
            try:
                img_arr = cv2.imread(os.path.join(path, img))[...,::-1] #convert BGR to RGB format
                resized_arr = cv2.resize(img_arr, (img_size, img_size)) # Reshaping images to preferred size
                data.append([resized_arr, class_num])
            except Exception as e:
                print(e)
    return np.array(data)

# %%
train = get_data('/content/OCT_Dataset')
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:15: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   from ipykernel import kernelapp as app

# %%
l = []
for i in train:
    if(i[1] == 0):
        l.append("CNVA")
    elif(i[1] == 1):
          l.append("DMEA")
    elif(i[1] == 2):
          l.append("DRUSENA")
    elif(i[1] == 3):
          l.append("NORMALA")
       
sns.set_style('darkgrid')
sns.countplot(l)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
plt.figure(figsize = (5,5))
plt.imshow(train[1][0])
plt.title(labels[train[0][1]])
# Out:
# Text(0.5, 1.0, 'CNVA')

# %%
x_train = []
y_train = []


for feature, label in train:
  x_train.append(feature)
  y_train.append(label)
x_train = np.array(x_train) / 255
x_train.reshape(-1, img_size, img_size, 1)
y_train = np.array(y_train)

# %%
# split with a stratified sampling
from sklearn.model_selection import train_test_split
(x_train, x_test, y_train, y_test) = train_test_split(x_train, y_train,
    test_size=0.15, stratify=y_train, random_state=42)

# %%
# !pip install -U -q tensorflow-addons

# %%
from tensorflow.keras import layers
from tensorflow import keras

import matplotlib.pyplot as plt
import tensorflow_addons as tfa
import tensorflow as tf
import numpy as np

# %%
y_train = keras.utils.to_categorical(
    y_train, num_classes=4, dtype='float32'
)
y_test = keras.utils.to_categorical(
    y_test, num_classes=4, dtype='float32'
)

# %%
num_classes = 4
input_shape = (32, 32, 3)

# %%
print(f"x_train shape: {x_train.shape} - y_train shape: {y_train.shape}")
print(f"x_test shape: {x_test.shape} - y_test shape: {y_test.shape}")
# Out:
# x_train shape: (111475, 32, 32, 3) - y_train shape: (111475, 4)
# x_test shape: (19673, 32, 32, 3) - y_test shape: (19673, 4)

# %%
import matplotlib.pyplot as plt
import numpy as np
import tensorflow as tf
import tensorflow_addons as tfa
from tensorflow import keras
from tensorflow.keras import layers

# %%
patch_size = (2, 2)  # 2-by-2 sized patches
dropout_rate = 0.03  # Dropout rate
num_heads = 4  # Attention heads
embed_dim = 64  # Embedding dimension
num_mlp = 64  # MLP layer size
qkv_bias = True  # Convert embedded patches to query, key, and values with a learnable additive value
window_size = 2  # Size of attention window
shift_size = 1  # Size of shifting window
image_dimension = 32  # Initial image size

num_patch_x = input_shape[0] // patch_size[0]
num_patch_y = input_shape[1] // patch_size[1]

learning_rate = 0.001
batch_size = 128
num_epochs = 100
validation_split = 0.1
weight_decay = 0.0001
label_smoothing = 0.1

# %%
def window_partition(x, window_size):
    _, height, width, channels = x.shape
    patch_num_y = height // window_size
    patch_num_x = width // window_size
    x = tf.reshape(
        x, shape=(-1, patch_num_y, window_size, patch_num_x, window_size, channels)
    )
    x = tf.transpose(x, (0, 1, 3, 2, 4, 5))
    windows = tf.reshape(x, shape=(-1, window_size, window_size, channels))
    return windows


def window_reverse(windows, window_size, height, width, channels):
    patch_num_y = height // window_size
    patch_num_x = width // window_size
    x = tf.reshape(
        windows,
        shape=(-1, patch_num_y, patch_num_x, window_size, window_size, channels),
    )
    x = tf.transpose(x, perm=(0, 1, 3, 2, 4, 5))
    x = tf.reshape(x, shape=(-1, height, width, channels))
    return x


class DropPath(layers.Layer):
    def __init__(self, drop_prob=None, **kwargs):
        super(DropPath, self).__init__(**kwargs)
        self.drop_prob = drop_prob

    def call(self, x):
        input_shape = tf.shape(x)
        batch_size = input_shape[0]
        rank = x.shape.rank
        shape = (batch_size,) + (1,) * (rank - 1)
        random_tensor = (1 - self.drop_prob) + tf.random.uniform(shape, dtype=x.dtype)
        path_mask = tf.floor(random_tensor)
        output = tf.math.divide(x, 1 - self.drop_prob) * path_mask
        return output

# %%
class WindowAttention(layers.Layer):
    def __init__(
        self, dim, window_size, num_heads, qkv_bias=True, dropout_rate=0.0, **kwargs
    ):
        super(WindowAttention, self).__init__(**kwargs)
        self.dim = dim
        self.window_size = window_size
        self.num_heads = num_heads
        self.scale = (dim // num_heads) ** -0.5
        self.qkv = layers.Dense(dim * 3, use_bias=qkv_bias)
        self.dropout = layers.Dropout(dropout_rate)
        self.proj = layers.Dense(dim)

    def build(self, input_shape):
        num_window_elements = (2 * self.window_size[0] - 1) * (
            2 * self.window_size[1] - 1
        )
        self.relative_position_bias_table = self.add_weight(
            shape=(num_window_elements, self.num_heads),
            initializer=tf.initializers.Zeros(),
            trainable=True,
        )
        coords_h = np.arange(self.window_size[0])
        coords_w = np.arange(self.window_size[1])
        coords_matrix = np.meshgrid(coords_h, coords_w, indexing="ij")
        coords = np.stack(coords_matrix)
        coords_flatten = coords.reshape(2, -1)
        relative_coords = coords_flatten[:, :, None] - coords_flatten[:, None, :]
        relative_coords = relative_coords.transpose([1, 2, 0])
        relative_coords[:, :, 0] += self.window_size[0] - 1
        relative_coords[:, :, 1] += self.window_size[1] - 1
        relative_coords[:, :, 0] *= 2 * self.window_size[1] - 1
        relative_position_index = relative_coords.sum(-1)

        self.relative_position_index = tf.Variable(
            initial_value=tf.convert_to_tensor(relative_position_index), trainable=False
        )

    def call(self, x, mask=None):
        _, size, channels = x.shape
        head_dim = channels // self.num_heads
        x_qkv = self.qkv(x)
        x_qkv = tf.reshape(x_qkv, shape=(-1, size, 3, self.num_heads, head_dim))
        x_qkv = tf.transpose(x_qkv, perm=(2, 0, 3, 1, 4))
        q, k, v = x_qkv[0], x_qkv[1], x_qkv[2]
        q = q * self.scale
        k = tf.transpose(k, perm=(0, 1, 3, 2))
        attn = q @ k

        num_window_elements = self.window_size[0] * self.window_size[1]
        relative_position_index_flat = tf.reshape(
            self.relative_position_index, shape=(-1,)
        )
        relative_position_bias = tf.gather(
            self.relative_position_bias_table, relative_position_index_flat
        )
        relative_position_bias = tf.reshape(
            relative_position_bias, shape=(num_window_elements, num_window_elements, -1)
        )
        relative_position_bias = tf.transpose(relative_position_bias, perm=(2, 0, 1))
        attn = attn + tf.expand_dims(relative_position_bias, axis=0)

        if mask is not None:
            nW = mask.get_shape()[0]
            mask_float = tf.cast(
                tf.expand_dims(tf.expand_dims(mask, axis=1), axis=0), tf.float32
            )
            attn = (
                tf.reshape(attn, shape=(-1, nW, self.num_heads, size, size))
                + mask_float
            )
            attn = tf.reshape(attn, shape=(-1, self.num_heads, size, size))
            attn = keras.activations.softmax(attn, axis=-1)
        else:
            attn = keras.activations.softmax(attn, axis=-1)
        attn = self.dropout(attn)

        x_qkv = attn @ v
        x_qkv = tf.transpose(x_qkv, perm=(0, 2, 1, 3))
        x_qkv = tf.reshape(x_qkv, shape=(-1, size, channels))
        x_qkv = self.proj(x_qkv)
        x_qkv = self.dropout(x_qkv)
        return x_qkv

# %%
class SwinTransformer(layers.Layer):
    def __init__(
        self,
        dim,
        num_patch,
        num_heads,
        window_size=7,
        shift_size=0,
        num_mlp=1024,
        qkv_bias=True,
        dropout_rate=0.0,
        **kwargs,
    ):
        super(SwinTransformer, self).__init__(**kwargs)

        self.dim = dim  # number of input dimensions
        self.num_patch = num_patch  # number of embedded patches
        self.num_heads = num_heads  # number of attention heads
        self.window_size = window_size  # size of window
        self.shift_size = shift_size  # size of window shift
        self.num_mlp = num_mlp  # number of MLP nodes

        self.norm1 = layers.LayerNormalization(epsilon=1e-5)
        self.attn = WindowAttention(
            dim,
            window_size=(self.window_size, self.window_size),
            num_heads=num_heads,
            qkv_bias=qkv_bias,
            dropout_rate=dropout_rate,
        )
        self.drop_path = DropPath(dropout_rate)
        self.norm2 = layers.LayerNormalization(epsilon=1e-5)

        self.mlp = keras.Sequential(
            [
                layers.Dense(num_mlp),
                layers.Activation(keras.activations.elu),
                layers.Dropout(dropout_rate),
                layers.Dense(dim),
                layers.Dropout(dropout_rate),
            ]
        )

        if min(self.num_patch) < self.window_size:
            self.shift_size = 0
            self.window_size = min(self.num_patch)

    def build(self, input_shape):
        if self.shift_size == 0:
            self.attn_mask = None
        else:
            height, width = self.num_patch
            h_slices = (
                slice(0, -self.window_size),
                slice(-self.window_size, -self.shift_size),
                slice(-self.shift_size, None),
            )
            w_slices = (
                slice(0, -self.window_size),
                slice(-self.window_size, -self.shift_size),
                slice(-self.shift_size, None),
            )
            mask_array = np.zeros((1, height, width, 1))
            count = 0
            for h in h_slices:
                for w in w_slices:
                    mask_array[:, h, w, :] = count
                    count += 1
            mask_array = tf.convert_to_tensor(mask_array)

            # mask array to windows
            mask_windows = window_partition(mask_array, self.window_size)
            mask_windows = tf.reshape(
                mask_windows, shape=[-1, self.window_size * self.window_size]
            )
            attn_mask = tf.expand_dims(mask_windows, axis=1) - tf.expand_dims(
                mask_windows, axis=2
            )
            attn_mask = tf.where(attn_mask != 0, -100.0, attn_mask)
            attn_mask = tf.where(attn_mask == 0, 0.0, attn_mask)
            self.attn_mask = tf.Variable(initial_value=attn_mask, trainable=False)

    def call(self, x):
        height, width = self.num_patch
        _, num_patches_before, channels = x.shape
        x_skip = x
        x = self.norm1(x)
        x = tf.reshape(x, shape=(-1, height, width, channels))
        if self.shift_size > 0:
            shifted_x = tf.roll(
                x, shift=[-self.shift_size, -self.shift_size], axis=[1, 2]
            )
        else:
            shifted_x = x

        x_windows = window_partition(shifted_x, self.window_size)
        x_windows = tf.reshape(
            x_windows, shape=(-1, self.window_size * self.window_size, channels)
        )
        attn_windows = self.attn(x_windows, mask=self.attn_mask)

        attn_windows = tf.reshape(
            attn_windows, shape=(-1, self.window_size, self.window_size, channels)
        )
        shifted_x = window_reverse(
            attn_windows, self.window_size, height, width, channels
        )
        if self.shift_size > 0:
            x = tf.roll(
                shifted_x, shift=[self.shift_size, self.shift_size], axis=[1, 2]
            )
        else:
            x = shifted_x

        x = tf.reshape(x, shape=(-1, height * width, channels))
        x = self.drop_path(x)
        x = x_skip + x
        x_skip = x
        x = self.norm2(x)
        x = self.mlp(x)
        x = self.drop_path(x)
        x = x_skip + x
        return x

# %%
class PatchExtract(layers.Layer):
    def __init__(self, patch_size, **kwargs):
        super(PatchExtract, self).__init__(**kwargs)
        self.patch_size_x = patch_size[0]
        self.patch_size_y = patch_size[0]

    def call(self, images):
        batch_size = tf.shape(images)[0]
        patches = tf.image.extract_patches(
            images=images,
            sizes=(1, self.patch_size_x, self.patch_size_y, 1),
            strides=(1, self.patch_size_x, self.patch_size_y, 1),
            rates=(1, 1, 1, 1),
            padding="VALID",
        )
        patch_dim = patches.shape[-1]
        patch_num = patches.shape[1]
        return tf.reshape(patches, (batch_size, patch_num * patch_num, patch_dim))


class PatchEmbedding(layers.Layer):
    def __init__(self, num_patch, embed_dim, **kwargs):
        super(PatchEmbedding, self).__init__(**kwargs)
        self.num_patch = num_patch
        self.proj = layers.Dense(embed_dim)
        self.pos_embed = layers.Embedding(input_dim=num_patch, output_dim=embed_dim)

    def call(self, patch):
        pos = tf.range(start=0, limit=self.num_patch, delta=1)
        return self.proj(patch) + self.pos_embed(pos)


class PatchMerging(tf.keras.layers.Layer):
    def __init__(self, num_patch, embed_dim):
        super(PatchMerging, self).__init__()
        self.num_patch = num_patch
        self.embed_dim = embed_dim
        self.linear_trans = layers.Dense(2 * embed_dim, use_bias=False)

    def call(self, x):
        height, width = self.num_patch
        _, _, C = x.get_shape().as_list()
        x = tf.reshape(x, shape=(-1, height, width, C))
        x0 = x[:, 0::2, 0::2, :]
        x1 = x[:, 1::2, 0::2, :]
        x2 = x[:, 0::2, 1::2, :]
        x3 = x[:, 1::2, 1::2, :]
        x = tf.concat((x0, x1, x2, x3), axis=-1)
        x = tf.reshape(x, shape=(-1, (height // 2) * (width // 2), 4 * C))
        return self.linear_trans(x)

# %%
input = layers.Input(input_shape)
x = layers.RandomCrop(image_dimension, image_dimension)(input)
x = layers.RandomFlip("horizontal")(x)
x = PatchExtract(patch_size)(x)
x = PatchEmbedding(num_patch_x * num_patch_y, embed_dim)(x)
x = SwinTransformer(
    dim=embed_dim,
    num_patch=(num_patch_x, num_patch_y),
    num_heads=num_heads,
    window_size=window_size,
    shift_size=0,
    num_mlp=num_mlp,
    qkv_bias=qkv_bias,
    dropout_rate=dropout_rate,
)(x)
x = SwinTransformer(
    dim=embed_dim,
    num_patch=(num_patch_x, num_patch_y),
    num_heads=num_heads,
    window_size=window_size,
    shift_size=shift_size,
    num_mlp=num_mlp,
    qkv_bias=qkv_bias,
    dropout_rate=dropout_rate,
)(x)
x = PatchMerging((num_patch_x, num_patch_y), embed_dim=embed_dim)(x)
x = layers.GlobalAveragePooling1D()(x)
output = layers.Dense(num_classes, activation="softmax")(x)

# %%
model = keras.Model(input, output)
model.compile(
    loss=keras.losses.CategoricalCrossentropy(label_smoothing=label_smoothing),
    optimizer=tfa.optimizers.Adam(
    learning_rate=0.001,
    beta_1=0.9,
    beta_2=0.999,
    epsilon=1e-07,
    amsgrad=False,
    name="Adam",
    **kwargs
),
    metrics=[
        keras.metrics.CategoricalAccuracy(name="accuracy"),
        keras.metrics.TopKCategoricalAccuracy(5, name="top-5-accuracy"),
    ],
)

history = model.fit(
    x_train,
    y_train,
    batch_size=batch_size,
    epochs=num_epochs,
    validation_split=validation_split,
)
# Out:
# Epoch 1/100
# 784/784 [==============================] - 44s 51ms/step - loss: 0.8531 - accuracy: 0.7383 - top-5-accuracy: 1.0000 - val_loss: 0.7874 - val_accuracy: 0.7782 - val_top-5-accuracy: 1.0000
# Epoch 2/100
# 784/784 [==============================] - 39s 49ms/step - loss: 0.7532 - accuracy: 0.8021 - top-5-accuracy: 1.0000 - val_loss: 0.7281 - val_accuracy: 0.8198 - val_top-5-accuracy: 1.0000
# Epoch 3/100
# 784/784 [==============================] - 39s 50ms/step - loss: 0.7229 - accuracy: 0.8192 - top-5-accuracy: 1.0000 - val_loss: 0.7270 - val_accuracy: 0.8188 - val_top-5-accuracy: 1.0000
# Epoch 4/100
# 784/784 [==============================] - 39s 50ms/step - loss: 0.7028 - accuracy: 0.8325 - top-5-accuracy: 1.0000 - val_loss: 0.6934 - val_accuracy: 0.8350 - val_top-5-accuracy: 1.0000
# Epoch 5/100
# 784/784 [==============================] - 39s 50ms/step - loss: 0.6911 - accuracy: 0.8379 - top-5-accuracy: 1.0000 - val_loss: 0.6755 - val_accuracy: 0.8421 - val_top-5-accuracy: 1.0000
# Epoch 6/100
# 784/784 [==============================] - 39s 50ms/step - loss: 0.6802 - accuracy: 0.8449 - top-5-accuracy: 1.0000 - val_loss: 0.6808 - val_accuracy: 0.8391 - val_top-5-accuracy: 1.0000
# Epoch 7/100
# 784/784 [==============================] - 39s 50ms/step - loss: 0.6700 - accuracy: 0.8509 - top-5-accuracy: 1.0000 - val_loss: 0.6478 - val_accuracy: 0.8611 - val_top-5-accuracy: 1.0000
# Epoch 8/100
# 784/784 [==============================] - 39s 49ms/step - loss: 0.6647 - accuracy: 0.8533 - top-5-accuracy: 1.0000 - val_loss: 0.6743 - val_accuracy: 0.8426 - val_top-5-accuracy: 1.0000
# Epoch 9/100
# 784/784 [==============================] - 39s 50ms/step - loss: 0.6564 - accuracy: 0.8584 - top-5-accuracy: 1.0000 - val_loss: 0.6375 - val_accuracy: 0.8671 - val_top-5-accuracy: 1.0000
# Epoch 10/100
# 784/784 [==============================] - 39s 50ms/step - loss: 0.6536 - accuracy: 0.8608 - top-5-accuracy: 1.0000 - val_loss: 0.6325 - val_accuracy: 0.8668 - val_top-5-accuracy: 1.0000
# Epoch 11/100
# 784/784 [==============================] - 39s 50ms/step - loss: 0.6457 - accuracy: 0.8649 - top-5-accuracy: 1.0000 - val_loss: 0.6556 - val_accuracy: 0.8603 - val_top-5-accuracy: 1.0000
# Epoch 12/100
# 784/784 [==============================] - 40s 50ms/step - loss: 0.6458 - accuracy: 0.8641 - top-5-accuracy: 1.0000 - val_loss: 0.6446 - val_accuracy: 0.8681 - val_top-5-accuracy: 1.0000
# Epoch 13/100
# 784/784 [==============================] - 39s 50ms/step - loss: 0.6394 - accuracy: 0.8683 - top-5-accuracy: 1.0000 - val_loss: 0.6406 - val_accuracy: 0.8629 - val_top-5-accuracy: 1.0000
# Epoch 14/100
# 784/784 [==============================] - 39s 50ms/step - loss: 0.6373 - accuracy: 0.8696 - top-5-accuracy: 1.0000 - val_loss: 0.6374 - val_accuracy: 0.8658 - val_top-5-accuracy: 1.0000
# Epoch 15/100
# 784/784 [==============================] - 39s 50ms/step - loss: 0.6359 - accuracy: 0.8711 - top-5-accuracy: 1.0000 - val_loss: 0.6266 - val_accuracy: 0.8734 - val_top-5-accuracy: 1.0000
# Epoch 16/100
# 784/784 [==============================] - 38s 49ms/step - loss: 0.6336 - accuracy: 0.8709 - top-5-accuracy: 1.0000 - val_loss: 0.6364 - val_accuracy: 0.8698 - val_top-5-accuracy: 1.0000
# Epoch 17/100
# 784/784 [==============================] - 39s 50ms/step - loss: 0.6334 - accuracy: 0.8720 - top-5-accuracy: 1.0000 - val_loss: 0.6262 - val_accuracy: 0.8718 - val_top-5-accuracy: 1.0000
# Epoch 18/100
# 784/784 [==============================] - 39s 50ms/step - loss: 0.6290 - accuracy: 0.8752 - top-5-accuracy: 1.0000 - val_loss: 0.6330 - val_accuracy: 0.8715 - val_top-5-accuracy: 1.0000
# Epoch 19/100
# 784/784 [==============================] - 39s 50ms/step - loss: 0.6276 - accuracy: 0.8751 - top-5-accuracy: 1.0000 - val_loss: 0.6318 - val_accuracy: 0.8689 - val_top-5-accuracy: 1.0000
# Epoch 20/100
# 784/784 [==============================] - 39s 50ms/step - loss: 0.6272 - accuracy: 0.8766 - top-5-accuracy: 1.0000 - val_loss: 0.6202 - val_accuracy: 0.8794 - val_top-5-accuracy: 1.0000
# Epoch 21/100
# 784/784 [==============================] - 39s 50ms/step - loss: 0.6250 - accuracy: 0.8763 - top-5-accuracy: 1.0000 - val_loss: 0.6149 - val_accuracy: 0.8828 - val_top-5-accuracy: 1.0000
# Epoch 22/100
# 784/784 [==============================] - 39s 50ms/step - loss: 0.6222 - accuracy: 0.8786 - top-5-accuracy: 1.0000 - val_loss: 0.6143 - val_accuracy: 0.8811 - val_top-5-accuracy: 1.0000
# Epoch 23/100
# 784/784 [==============================] - 38s 48ms/step - loss: 0.6218 - accuracy: 0.8786 - top-5-accuracy: 1.0000 - val_loss: 0.6141 - val_accuracy: 0.8836 - val_top-5-accuracy: 1.0000
# Epoch 24/100
# 784/784 [==============================] - 39s 50ms/step - loss: 0.6223 - accuracy: 0.8790 - top-5-accuracy: 1.0000 - val_loss: 0.6229 - val_accuracy: 0.8764 - val_top-5-accuracy: 1.0000
# Epoch 25/100
# 784/784 [==============================] - 40s 51ms/step - loss: 0.6201 - accuracy: 0.8791 - top-5-accuracy: 1.0000 - val_loss: 0.6252 - val_accuracy: 0.8713 - val_top-5-accuracy: 1.0000
# Epoch 26/100
# 784/784 [==============================] - 41s 52ms/step - loss: 0.6200 - accuracy: 0.8806 - top-5-accuracy: 1.0000 - val_loss: 0.6179 - val_accuracy: 0.8811 - val_top-5-accuracy: 1.0000
# Epoch 27/100
# 784/784 [==============================] - 39s 49ms/step - loss: 0.6189 - accuracy: 0.8805 - top-5-accuracy: 1.0000 - val_loss: 0.6286 - val_accuracy: 0.8662 - val_top-5-accuracy: 1.0000
# Epoch 28/100
# 784/784 [==============================] - 40s 51ms/step - loss: 0.6176 - accuracy: 0.8823 - top-5-accuracy: 1.0000 - val_loss: 0.6134 - val_accuracy: 0.8778 - val_top-5-accuracy: 1.0000
# Epoch 29/100
# 784/784 [==============================] - 39s 49ms/step - loss: 0.6158 - accuracy: 0.8825 - top-5-accuracy: 1.0000 - val_loss: 0.6141 - val_accuracy: 0.8816 - val_top-5-accuracy: 1.0000
# Epoch 30/100
# 784/784 [==============================] - 39s 49ms/step - loss: 0.6148 - accuracy: 0.8826 - top-5-accuracy: 1.0000 - val_loss: 0.6102 - val_accuracy: 0.8855 - val_top-5-accuracy: 1.0000
# Epoch 31/100
# 784/784 [==============================] - 39s 50ms/step - loss: 0.6147 - accuracy: 0.8823 - top-5-accuracy: 1.0000 - val_loss: 0.6156 - val_accuracy: 0.8820 - val_top-5-accuracy: 1.0000
# Epoch 32/100
# 784/784 [==============================] - 39s 49ms/step - loss: 0.6147 - accuracy: 0.8835 - top-5-accuracy: 1.0000 - val_loss: 0.6086 - val_accuracy: 0.8835 - val_top-5-accuracy: 1.0000
# Epoch 33/100
# 784/784 [==============================] - 39s 49ms/step - loss: 0.6145 - accuracy: 0.8835 - top-5-accuracy: 1.0000 - val_loss: 0.6127 - val_accuracy: 0.8842 - val_top-5-accuracy: 1.0000
# Epoch 34/100
# 784/784 [==============================] - 39s 49ms/step - loss: 0.6119 - accuracy: 0.8846 - top-5-accuracy: 1.0000 - val_loss: 0.6193 - val_accuracy: 0.8760 - val_top-5-accuracy: 1.0000
# Epoch 35/100
# 784/784 [==============================] - 39s 49ms/step - loss: 0.6126 - accuracy: 0.8837 - top-5-accuracy: 1.0000 - val_loss: 0.6100 - val_accuracy: 0.8859 - val_top-5-accuracy: 1.0000
# Epoch 36/100
# 784/784 [==============================] - 38s 49ms/step - loss: 0.6127 - accuracy: 0.8837 - top-5-accuracy: 1.0000 - val_loss: 0.6108 - val_accuracy: 0.8835 - val_top-5-accuracy: 1.0000
# Epoch 37/100
# 784/784 [==============================] - 38s 49ms/step - loss: 0.6128 - accuracy: 0.8835 - top-5-accuracy: 1.0000 - val_loss: 0.5974 - val_accuracy: 0.8912 - val_top-5-accuracy: 1.0000
# Epoch 38/100
# 784/784 [==============================] - 39s 49ms/step - loss: 0.6106 - accuracy: 0.8854 - top-5-accuracy: 1.0000 - val_loss: 0.6126 - val_accuracy: 0.8814 - val_top-5-accuracy: 1.0000
# Epoch 39/100
# 784/784 [==============================] - 39s 49ms/step - loss: 0.6108 - accuracy: 0.8842 - top-5-accuracy: 1.0000 - val_loss: 0.6075 - val_accuracy: 0.8861 - val_top-5-accuracy: 1.0000
# Epoch 40/100
# 784/784 [==============================] - 39s 49ms/step - loss: 0.6099 - accuracy: 0.8861 - top-5-accuracy: 1.0000 - val_loss: 0.6378 - val_accuracy: 0.8693 - val_top-5-accuracy: 1.0000
# Epoch 41/100
# 784/784 [==============================] - 39s 49ms/step - loss: 0.6078 - accuracy: 0.8860 - top-5-accuracy: 1.0000 - val_loss: 0.6021 - val_accuracy: 0.8850 - val_top-5-accuracy: 1.0000
# Epoch 42/100
# 784/784 [==============================] - 38s 49ms/step - loss: 0.6102 - accuracy: 0.8860 - top-5-accuracy: 1.0000 - val_loss: 0.6078 - val_accuracy: 0.8839 - val_top-5-accuracy: 1.0000
# Epoch 43/100
# 784/784 [==============================] - 38s 49ms/step - loss: 0.6088 - accuracy: 0.8863 - top-5-accuracy: 1.0000 - val_loss: 0.6110 - val_accuracy: 0.8860 - val_top-5-accuracy: 1.0000
# Epoch 44/100
# 784/784 [==============================] - 39s 49ms/step - loss: 0.6073 - accuracy: 0.8877 - top-5-accuracy: 1.0000 - val_loss: 0.6081 - val_accuracy: 0.8833 - val_top-5-accuracy: 1.0000
# Epoch 45/100
# 784/784 [==============================] - 39s 49ms/step - loss: 0.6077 - accuracy: 0.8864 - top-5-accuracy: 1.0000 - val_loss: 0.6106 - val_accuracy: 0.8847 - val_top-5-accuracy: 1.0000
# Epoch 46/100
# 784/784 [==============================] - 39s 49ms/step - loss: 0.6063 - accuracy: 0.8888 - top-5-accuracy: 1.0000 - val_loss: 0.6038 - val_accuracy: 0.8867 - val_top-5-accuracy: 1.0000
# Epoch 47/100
# 784/784 [==============================] - 39s 49ms/step - loss: 0.6086 - accuracy: 0.8859 - top-5-accuracy: 1.0000 - val_loss: 0.6049 - val_accuracy: 0.8869 - val_top-5-accuracy: 1.0000
# Epoch 48/100
# 784/784 [==============================] - 39s 50ms/step - loss: 0.6064 - accuracy: 0.8876 - top-5-accuracy: 1.0000 - val_loss: 0.5991 - val_accuracy: 0.8876 - val_top-5-accuracy: 1.0000
# Epoch 49/100
# 784/784 [==============================] - 39s 50ms/step - loss: 0.6051 - accuracy: 0.8883 - top-5-accuracy: 1.0000 - val_loss: 0.6116 - val_accuracy: 0.8851 - val_top-5-accuracy: 1.0000
# Epoch 50/100
# 784/784 [==============================] - 38s 49ms/step - loss: 0.6052 - accuracy: 0.8884 - top-5-accuracy: 1.0000 - val_loss: 0.6299 - val_accuracy: 0.8706 - val_top-5-accuracy: 1.0000
# Epoch 51/100
# 784/784 [==============================] - 39s 49ms/step - loss: 0.6057 - accuracy: 0.8883 - top-5-accuracy: 1.0000 - val_loss: 0.6059 - val_accuracy: 0.8875 - val_top-5-accuracy: 1.0000
# Epoch 52/100
# 784/784 [==============================] - 39s 50ms/step - loss: 0.6070 - accuracy: 0.8873 - top-5-accuracy: 1.0000 - val_loss: 0.6142 - val_accuracy: 0.8824 - val_top-5-accuracy: 1.0000
# Epoch 53/100
# 784/784 [==============================] - 39s 50ms/step - loss: 0.6038 - accuracy: 0.8894 - top-5-accuracy: 1.0000 - val_loss: 0.6093 - val_accuracy: 0.8815 - val_top-5-accuracy: 1.0000
# Epoch 54/100
# 784/784 [==============================] - 39s 50ms/step - loss: 0.6043 - accuracy: 0.8887 - top-5-accuracy: 1.0000 - val_loss: 0.6317 - val_accuracy: 0.8680 - val_top-5-accuracy: 1.0000
# Epoch 55/100
# 784/784 [==============================] - 39s 50ms/step - loss: 0.6048 - accuracy: 0.8891 - top-5-accuracy: 1.0000 - val_loss: 0.6184 - val_accuracy: 0.8791 - val_top-5-accuracy: 1.0000
# Epoch 56/100
# 784/784 [==============================] - 39s 50ms/step - loss: 0.6049 - accuracy: 0.8879 - top-5-accuracy: 1.0000 - val_loss: 0.5965 - val_accuracy: 0.8933 - val_top-5-accuracy: 1.0000
# Epoch 57/100
# 784/784 [==============================] - 39s 50ms/step - loss: 0.6021 - accuracy: 0.8901 - top-5-accuracy: 1.0000 - val_loss: 0.5936 - val_accuracy: 0.8937 - val_top-5-accuracy: 1.0000
# Epoch 58/100
# 784/784 [==============================] - 39s 50ms/step - loss: 0.6031 - accuracy: 0.8895 - top-5-accuracy: 1.0000 - val_loss: 0.6103 - val_accuracy: 0.8869 - val_top-5-accuracy: 1.0000
# Epoch 59/100
# 784/784 [==============================] - 39s 50ms/step - loss: 0.6029 - accuracy: 0.8900 - top-5-accuracy: 1.0000 - val_loss: 0.5986 - val_accuracy: 0.8869 - val_top-5-accuracy: 1.0000
# Epoch 60/100
# 784/784 [==============================] - 40s 51ms/step - loss: 0.6017 - accuracy: 0.8902 - top-5-accuracy: 1.0000 - val_loss: 0.6005 - val_accuracy: 0.8907 - val_top-5-accuracy: 1.0000
# Epoch 61/100
# 784/784 [==============================] - 39s 50ms/step - loss: 0.6020 - accuracy: 0.8901 - top-5-accuracy: 1.0000 - val_loss: 0.6168 - val_accuracy: 0.8782 - val_top-5-accuracy: 1.0000
# Epoch 62/100
# 784/784 [==============================] - 39s 50ms/step - loss: 0.6028 - accuracy: 0.8902 - top-5-accuracy: 1.0000 - val_loss: 0.6110 - val_accuracy: 0.8846 - val_top-5-accuracy: 1.0000
# Epoch 63/100
# 784/784 [==============================] - 39s 50ms/step - loss: 0.6007 - accuracy: 0.8922 - top-5-accuracy: 1.0000 - val_loss: 0.6105 - val_accuracy: 0.8827 - val_top-5-accuracy: 1.0000
# Epoch 64/100
# 784/784 [==============================] - 39s 50ms/step - loss: 0.6026 - accuracy: 0.8903 - top-5-accuracy: 1.0000 - val_loss: 0.6113 - val_accuracy: 0.8816 - val_top-5-accuracy: 1.0000
# Epoch 65/100
# 784/784 [==============================] - 40s 51ms/step - loss: 0.6023 - accuracy: 0.8909 - top-5-accuracy: 1.0000 - val_loss: 0.6016 - val_accuracy: 0.8872 - val_top-5-accuracy: 1.0000
# Epoch 66/100
# 784/784 [==============================] - 39s 50ms/step - loss: 0.6011 - accuracy: 0.8913 - top-5-accuracy: 1.0000 - val_loss: 0.6162 - val_accuracy: 0.8831 - val_top-5-accuracy: 1.0000
# Epoch 67/100
# 784/784 [==============================] - 39s 50ms/step - loss: 0.6010 - accuracy: 0.8916 - top-5-accuracy: 1.0000 - val_loss: 0.6005 - val_accuracy: 0.8895 - val_top-5-accuracy: 1.0000
# Epoch 68/100
# 784/784 [==============================] - 39s 49ms/step - loss: 0.6022 - accuracy: 0.8896 - top-5-accuracy: 1.0000 - val_loss: 0.6043 - val_accuracy: 0.8864 - val_top-5-accuracy: 1.0000
# Epoch 69/100
# 784/784 [==============================] - 38s 49ms/step - loss: 0.6024 - accuracy: 0.8892 - top-5-accuracy: 1.0000 - val_loss: 0.6019 - val_accuracy: 0.8864 - val_top-5-accuracy: 1.0000
# Epoch 70/100
# 784/784 [==============================] - 38s 49ms/step - loss: 0.6006 - accuracy: 0.8905 - top-5-accuracy: 1.0000 - val_loss: 0.6046 - val_accuracy: 0.8869 - val_top-5-accuracy: 1.0000
# Epoch 71/100
# 784/784 [==============================] - 39s 49ms/step - loss: 0.6007 - accuracy: 0.8903 - top-5-accuracy: 1.0000 - val_loss: 0.5990 - val_accuracy: 0.8892 - val_top-5-accuracy: 1.0000
# Epoch 72/100
# 784/784 [==============================] - 39s 49ms/step - loss: 0.6000 - accuracy: 0.8904 - top-5-accuracy: 1.0000 - val_loss: 0.5925 - val_accuracy: 0.8968 - val_top-5-accuracy: 1.0000
# Epoch 73/100
# 784/784 [==============================] - 39s 49ms/step - loss: 0.6004 - accuracy: 0.8916 - top-5-accuracy: 1.0000 - val_loss: 0.5998 - val_accuracy: 0.8928 - val_top-5-accuracy: 1.0000
# Epoch 74/100
# 784/784 [==============================] - 38s 49ms/step - loss: 0.6014 - accuracy: 0.8905 - top-5-accuracy: 1.0000 - val_loss: 0.6010 - val_accuracy: 0.8884 - val_top-5-accuracy: 1.0000
# Epoch 75/100
# 784/784 [==============================] - 39s 49ms/step - loss: 0.6006 - accuracy: 0.8924 - top-5-accuracy: 1.0000 - val_loss: 0.6023 - val_accuracy: 0.8903 - val_top-5-accuracy: 1.0000
# Epoch 76/100
# 784/784 [==============================] - 39s 49ms/step - loss: 0.5993 - accuracy: 0.8915 - top-5-accuracy: 1.0000 - val_loss: 0.5965 - val_accuracy: 0.8897 - val_top-5-accuracy: 1.0000
# Epoch 77/100
# 784/784 [==============================] - 38s 49ms/step - loss: 0.5991 - accuracy: 0.8922 - top-5-accuracy: 1.0000 - val_loss: 0.6071 - val_accuracy: 0.8867 - val_top-5-accuracy: 1.0000
# Epoch 78/100
# 784/784 [==============================] - 38s 49ms/step - loss: 0.6005 - accuracy: 0.8912 - top-5-accuracy: 1.0000 - val_loss: 0.6033 - val_accuracy: 0.8914 - val_top-5-accuracy: 1.0000
# Epoch 79/100
# 784/784 [==============================] - 38s 49ms/step - loss: 0.5995 - accuracy: 0.8915 - top-5-accuracy: 1.0000 - val_loss: 0.5999 - val_accuracy: 0.8920 - val_top-5-accuracy: 1.0000
# Epoch 80/100
# 784/784 [==============================] - 39s 49ms/step - loss: 0.5984 - accuracy: 0.8922 - top-5-accuracy: 1.0000 - val_loss: 0.5986 - val_accuracy: 0.8911 - val_top-5-accuracy: 1.0000
# Epoch 81/100
# 784/784 [==============================] - 39s 50ms/step - loss: 0.5998 - accuracy: 0.8918 - top-5-accuracy: 1.0000 - val_loss: 0.5908 - val_accuracy: 0.8945 - val_top-5-accuracy: 1.0000
# Epoch 82/100
# 784/784 [==============================] - 39s 49ms/step - loss: 0.5974 - accuracy: 0.8929 - top-5-accuracy: 1.0000 - val_loss: 0.6117 - val_accuracy: 0.8794 - val_top-5-accuracy: 1.0000
# Epoch 83/100
# 784/784 [==============================] - 39s 50ms/step - loss: 0.5981 - accuracy: 0.8939 - top-5-accuracy: 1.0000 - val_loss: 0.5999 - val_accuracy: 0.8933 - val_top-5-accuracy: 1.0000
# Epoch 84/100
# 784/784 [==============================] - 39s 50ms/step - loss: 0.6002 - accuracy: 0.8909 - top-5-accuracy: 1.0000 - val_loss: 0.5905 - val_accuracy: 0.8974 - val_top-5-accuracy: 1.0000
# Epoch 85/100
# 784/784 [==============================] - 39s 50ms/step - loss: 0.5964 - accuracy: 0.8938 - top-5-accuracy: 1.0000 - val_loss: 0.5942 - val_accuracy: 0.8919 - val_top-5-accuracy: 1.0000
# Epoch 86/100
# 784/784 [==============================] - 39s 50ms/step - loss: 0.5990 - accuracy: 0.8919 - top-5-accuracy: 1.0000 - val_loss: 0.6071 - val_accuracy: 0.8855 - val_top-5-accuracy: 1.0000
# Epoch 87/100
# 784/784 [==============================] - 39s 50ms/step - loss: 0.5991 - accuracy: 0.8920 - top-5-accuracy: 1.0000 - val_loss: 0.5912 - val_accuracy: 0.8970 - val_top-5-accuracy: 1.0000
# Epoch 88/100
# 784/784 [==============================] - 39s 49ms/step - loss: 0.5970 - accuracy: 0.8935 - top-5-accuracy: 1.0000 - val_loss: 0.5949 - val_accuracy: 0.8903 - val_top-5-accuracy: 1.0000
# Epoch 89/100
# 784/784 [==============================] - 39s 49ms/step - loss: 0.5971 - accuracy: 0.8946 - top-5-accuracy: 1.0000 - val_loss: 0.6114 - val_accuracy: 0.8800 - val_top-5-accuracy: 1.0000
# Epoch 90/100
# 784/784 [==============================] - 39s 49ms/step - loss: 0.5979 - accuracy: 0.8936 - top-5-accuracy: 1.0000 - val_loss: 0.5890 - val_accuracy: 0.8963 - val_top-5-accuracy: 1.0000
# Epoch 91/100
# 784/784 [==============================] - 39s 49ms/step - loss: 0.5984 - accuracy: 0.8925 - top-5-accuracy: 1.0000 - val_loss: 0.5936 - val_accuracy: 0.8924 - val_top-5-accuracy: 1.0000
# Epoch 92/100
# 784/784 [==============================] - 39s 49ms/step - loss: 0.5975 - accuracy: 0.8932 - top-5-accuracy: 1.0000 - val_loss: 0.6065 - val_accuracy: 0.8906 - val_top-5-accuracy: 1.0000
# Epoch 93/100
# 784/784 [==============================] - 39s 49ms/step - loss: 0.5983 - accuracy: 0.8916 - top-5-accuracy: 1.0000 - val_loss: 0.5961 - val_accuracy: 0.8922 - val_top-5-accuracy: 1.0000
# Epoch 94/100
# 784/784 [==============================] - 39s 49ms/step - loss: 0.5961 - accuracy: 0.8948 - top-5-accuracy: 1.0000 - val_loss: 0.5950 - val_accuracy: 0.8947 - val_top-5-accuracy: 1.0000
# Epoch 95/100
# 784/784 [==============================] - 38s 49ms/step - loss: 0.5980 - accuracy: 0.8937 - top-5-accuracy: 1.0000 - val_loss: 0.5989 - val_accuracy: 0.8933 - val_top-5-accuracy: 1.0000
# Epoch 96/100
# 784/784 [==============================] - 38s 49ms/step - loss: 0.5963 - accuracy: 0.8930 - top-5-accuracy: 1.0000 - val_loss: 0.5908 - val_accuracy: 0.8962 - val_top-5-accuracy: 1.0000
# Epoch 97/100
# 784/784 [==============================] - 39s 49ms/step - loss: 0.5973 - accuracy: 0.8924 - top-5-accuracy: 1.0000 - val_loss: 0.5983 - val_accuracy: 0.8907 - val_top-5-accuracy: 1.0000
# Epoch 98/100
# 784/784 [==============================] - 39s 49ms/step - loss: 0.5971 - accuracy: 0.8933 - top-5-accuracy: 1.0000 - val_loss: 0.5908 - val_accuracy: 0.8943 - val_top-5-accuracy: 1.0000
# Epoch 99/100
# 784/784 [==============================] - 38s 49ms/step - loss: 0.5968 - accuracy: 0.8931 - top-5-accuracy: 1.0000 - val_loss: 0.5930 - val_accuracy: 0.8956 - val_top-5-accuracy: 1.0000
# Epoch 100/100
# 784/784 [==============================] - 39s 49ms/step - loss: 0.5959 - accuracy: 0.8935 - top-5-accuracy: 1.0000 - val_loss: 0.6014 - val_accuracy: 0.8873 - val_top-5-accuracy: 1.0000
